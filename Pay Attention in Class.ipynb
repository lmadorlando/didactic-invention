# %% [markdown]
# # Heading
# ## Subheading

# %% [markdown]
# Regular Text
# * list item 1
# * list item 2

# %% [markdown]
# 1. numbered list item
# 2. other numbered list item

# %%
print("hello, pandemic world")
# Out:
# hello, pandemic world
